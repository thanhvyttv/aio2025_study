# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import os
import cv2
import matplotlib.pyplot as plt
from torchvision.transforms import Resize
from torchvision.io import read_image

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

device = torch.device("mps" if torch.mps.is_available() else "cpu")
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)

# %%
data_dir = "./data/[Data]_Ex3_FER-2013"
train_dir = data_dir + "/train"
test_dir = data_dir + "/test"

classes = os.listdir(train_dir)
classes
# Out:
# ['happy', 'sad', 'fear', 'surprise', 'neutral', 'angry', 'disgust']

# %%
label2idx = {cls: idx for idx, cls in enumerate(classes)}
idx2label = {idx: cls for cls, idx in label2idx.items()}

print(label2idx)
print(idx2label)
# Out:
# {'happy': 0, 'sad': 1, 'fear': 2, 'surprise': 3, 'neutral': 4, 'angry': 5, 'disgust': 6}
# {0: 'happy', 1: 'sad', 2: 'fear', 3: 'surprise', 4: 'neutral', 5: 'angry', 6: 'disgust'}

# %%
img_height, img_width = (128, 128)
print(f"Image height: {img_height}")
print(f"Image width: {img_width}")
# Out:
# Image height: 128
# Image width: 128

# %%
class ImageDataset(Dataset):
    def __init__(self, img_dir, norm, label2idx, split="train", train_ratio=0.8):
        self.resize = Resize((img_height, img_width))
        self.norm = norm
        self.split = split
        self.train_ratio = train_ratio
        self.img_dir = img_dir
        self.label2idx = label2idx
        self.img_paths, self.img_labels = self.read_img_files()

        if split in ["train", "val"] and "train" in img_dir.lower():
            train_data, val_data = train_test_split(
                list(zip(self.img_paths, self.img_labels)),
                train_size=train_ratio,
                random_state=random_state,
                stratify=self.img_labels,
            )
            if split == "train":
                self.img_paths, self.img_labels = zip(*train_data)
            elif split == "val":
                self.img_paths, self.img_labels = zip(*val_data)

    def read_img_files(self):
        img_paths = []
        img_labels = []
        for cls in self.label2idx.keys():
            for img in os.listdir(os.path.join(self.img_dir, cls)):
                img_paths.append(os.path.join(self.img_dir, cls, img))
                img_labels.append(cls)
        return img_paths, img_labels

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, index):
        img_path = self.img_paths[index]
        cls = self.img_labels[index]
        img = self.resize(read_image(img_path))
        img = img.type(torch.float32)
        label = self.label2idx[cls]
        if self.norm:
            img = (img / 127.5) - 1

        return img, label

# %%
batch_size = 256

train_dataset = ImageDataset(train_dir, True, label2idx, split="train")
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

val_dataset = ImageDataset(train_dir, True, label2idx, split="val")
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

test_dataset = ImageDataset(test_dir, True, label2idx, split="test")
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims * 4)
        self.linear2 = nn.Linear(hidden_dims * 4, hidden_dims * 2)
        self.linear3 = nn.Linear(hidden_dims * 2, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = nn.Flatten()(x)
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        x = self.linear3(x)
        x = F.relu(x)
        output = self.output(x)
        return output.squeeze(1)

# %%
input_dims = img_height * img_width
output_dims = len(classes)
hidden_dims = 128
lr = 1e-2

model = MLP(input_dims=input_dims, hidden_dims=hidden_dims, output_dims=output_dims).to(
    device
)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)


def compute_accuracy(y_hat, y_true):
    _, y_hat = torch.max(y_hat, dim=1)
    correct = (y_hat == y_true).sum().item()
    accuracy = correct / len(y_true)
    return accuracy

# %%
epochs = 100
train_losses = []
val_losses = []
train_accs = []
val_accs = []

for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    train_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

        train_predict.append(outputs.detach().cpu())
        train_target.append(y_samples.cpu())
    train_loss /= len(train_loader)
    train_losses.append(train_loss)

    train_predict = torch.cat(train_predict)
    train_target = torch.cat(train_target)
    train_acc = compute_accuracy(train_predict, train_target)
    train_accs.append(train_acc)

    val_loss = 0.0
    val_target = []
    val_predict = []
    model.eval()
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_loss += criterion(outputs, y_samples).item()

            val_predict.append(outputs.cpu())
            val_target.append(y_samples.cpu())

        val_loss /= len(val_loader)
        val_losses.append(val_loss)

        val_predict = torch.cat(val_predict)
        val_target = torch.cat(val_target)
        val_acc = compute_accuracy(val_predict, val_target)
        val_accs.append(val_acc)

        print(
            f"\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}"
        )
# Out:
# EPOCH 1:	Training loss: 1.911	Validation loss: 1.873
#
# EPOCH 2:	Training loss: 1.840	Validation loss: 1.811
#
# EPOCH 3:	Training loss: 1.798	Validation loss: 1.785
#
# EPOCH 4:	Training loss: 1.779	Validation loss: 1.772
#
# EPOCH 5:	Training loss: 1.764	Validation loss: 1.759
#
# EPOCH 6:	Training loss: 1.748	Validation loss: 1.743
#
# EPOCH 7:	Training loss: 1.728	Validation loss: 1.723
#
# EPOCH 8:	Training loss: 1.705	Validation loss: 1.701
#
# EPOCH 9:	Training loss: 1.682	Validation loss: 1.681
#
# EPOCH 10:	Training loss: 1.661	Validation loss: 1.666
#
# EPOCH 11:	Training loss: 1.646	Validation loss: 1.654
#
# EPOCH 12:	Training loss: 1.632	Validation loss: 1.644
#
# EPOCH 13:	Training loss: 1.621	Validation loss: 1.636
#
# EPOCH 14:	Training loss: 1.611	Validation loss: 1.630
#
# EPOCH 15:	Training loss: 1.602	Validation loss: 1.623
#
# EPOCH 16:	Training loss: 1.593	Validation loss: 1.617
#
# EPOCH 17:	Training loss: 1.583	Validation loss: 1.612
#
# EPOCH 18:	Training loss: 1.575	Validation loss: 1.605
#
# EPOCH 19:	Training loss: 1.567	Validation loss: 1.603
#
# EPOCH 20:	Training loss: 1.558	Validation loss: 1.598
#
# EPOCH 21:	Training loss: 1.550	Validation loss: 1.588
#
# EPOCH 22:	Training loss: 1.541	Validation loss: 1.587
#
# EPOCH 23:	Training loss: 1.531	Validation loss: 1.580
#
# EPOCH 24:	Training loss: 1.522	Validation loss: 1.580
#
# EPOCH 25:	Training loss: 1.514	Validation loss: 1.568
#
# EPOCH 26:	Training loss: 1.505	Validation loss: 1.570
#
# EPOCH 27:	Training loss: 1.497	Validation loss: 1.568
#
# EPOCH 28:	Training loss: 1.487	Validation loss: 1.560
#
# EPOCH 29:	Training loss: 1.478	Validation loss: 1.554
#
# EPOCH 30:	Training loss: 1.469	Validation loss: 1.577
#
# EPOCH 31:	Training loss: 1.459	Validation loss: 1.547
#
# EPOCH 32:	Training loss: 1.447	Validation loss: 1.544
#
# EPOCH 33:	Training loss: 1.442	Validation loss: 1.539
#
# EPOCH 34:	Training loss: 1.434	Validation loss: 1.555
#
# EPOCH 35:	Training loss: 1.422	Validation loss: 1.553
#
# EPOCH 36:	Training loss: 1.415	Validation loss: 1.567
#
# EPOCH 37:	Training loss: 1.405	Validation loss: 1.565
#
# EPOCH 38:	Training loss: 1.401	Validation loss: 1.542
#
# EPOCH 39:	Training loss: 1.389	Validation loss: 1.534
#
# EPOCH 40:	Training loss: 1.375	Validation loss: 1.532
#
# EPOCH 41:	Training loss: 1.378	Validation loss: 1.571
#
# EPOCH 42:	Training loss: 1.357	Validation loss: 1.536
#
# EPOCH 43:	Training loss: 1.362	Validation loss: 1.536
#
# EPOCH 44:	Training loss: 1.346	Validation loss: 1.538
#
# EPOCH 45:	Training loss: 1.340	Validation loss: 1.527
#
# EPOCH 46:	Training loss: 1.329	Validation loss: 1.528
#
# EPOCH 47:	Training loss: 1.312	Validation loss: 1.538
#
# EPOCH 48:	Training loss: 1.303	Validation loss: 1.554
#
# EPOCH 49:	Training loss: 1.299	Validation loss: 1.538
#
# EPOCH 50:	Training loss: 1.280	Validation loss: 1.545
#
# EPOCH 51:	Training loss: 1.275	Validation loss: 1.552
#
# EPOCH 52:	Training loss: 1.260	Validation loss: 1.531
#
# EPOCH 53:	Training loss: 1.259	Validation loss: 1.550
#
# EPOCH 54:	Training loss: 1.258	Validation loss: 1.562
#
# EPOCH 55:	Training loss: 1.227	Validation loss: 1.545
#
# EPOCH 56:	Training loss: 1.218	Validation loss: 1.607
#
# EPOCH 57:	Training loss: 1.219	Validation loss: 1.657
#
# EPOCH 58:	Training loss: 1.221	Validation loss: 1.569
#
# EPOCH 59:	Training loss: 1.185	Validation loss: 1.547
#
# EPOCH 60:	Training loss: 1.178	Validation loss: 1.558
#
# EPOCH 61:	Training loss: 1.186	Validation loss: 1.574
#
# EPOCH 62:	Training loss: 1.148	Validation loss: 1.597
#
# EPOCH 63:	Training loss: 1.155	Validation loss: 1.561
#
# EPOCH 64:	Training loss: 1.144	Validation loss: 1.623
#
# EPOCH 65:	Training loss: 1.133	Validation loss: 1.590
#
# EPOCH 66:	Training loss: 1.109	Validation loss: 1.586
#
# EPOCH 67:	Training loss: 1.107	Validation loss: 1.585
#
# EPOCH 68:	Training loss: 1.101	Validation loss: 1.628
#
# EPOCH 69:	Training loss: 1.089	Validation loss: 1.749
#
# EPOCH 70:	Training loss: 1.092	Validation loss: 1.649
#
# EPOCH 71:	Training loss: 1.063	Validation loss: 1.709
#
# EPOCH 72:	Training loss: 1.048	Validation loss: 1.717
#
# EPOCH 73:	Training loss: 1.036	Validation loss: 1.666
#
# EPOCH 74:	Training loss: 1.022	Validation loss: 1.617
#
# EPOCH 75:	Training loss: 1.037	Validation loss: 1.711
#
# EPOCH 76:	Training loss: 1.011	Validation loss: 1.656
#
# EPOCH 77:	Training loss: 0.971	Validation loss: 1.744
#
# EPOCH 78:	Training loss: 0.993	Validation loss: 1.798
#
# EPOCH 79:	Training loss: 0.986	Validation loss: 1.811
#
# EPOCH 80:	Training loss: 0.948	Validation loss: 2.034
#
# EPOCH 81:	Training loss: 0.967	Validation loss: 1.699
#
# EPOCH 82:	Training loss: 0.927	Validation loss: 1.692
#
# EPOCH 83:	Training loss: 0.918	Validation loss: 1.841
#
# EPOCH 84:	Training loss: 0.939	Validation loss: 1.726
#
# EPOCH 85:	Training loss: 0.900	Validation loss: 1.715
#
# EPOCH 86:	Training loss: 0.891	Validation loss: 1.764
#
# EPOCH 87:	Training loss: 0.868	Validation loss: 1.780
#
# EPOCH 88:	Training loss: 0.875	Validation loss: 1.901
#
# EPOCH 89:	Training loss: 0.860	Validation loss: 1.898
#
# EPOCH 90:	Training loss: 0.839	Validation loss: 1.886
#
# EPOCH 91:	Training loss: 0.830	Validation loss: 1.729
#
# EPOCH 92:	Training loss: 0.804	Validation loss: 1.950
#
# EPOCH 93:	Training loss: 0.808	Validation loss: 1.878
#
# EPOCH 94:	Training loss: 0.814	Validation loss: 1.895
#
# EPOCH 95:	Training loss: 0.779	Validation loss: 1.914
#
# EPOCH 96:	Training loss: 0.774	Validation loss: 1.896
#
# EPOCH 97:	Training loss: 0.772	Validation loss: 1.871
#
# EPOCH 98:	Training loss: 0.744	Validation loss: 2.189
#
# EPOCH 99:	Training loss: 0.747	Validation loss: 1.987
#
# EPOCH 100:	Training loss: 0.745	Validation loss: 2.113

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))
ax[0, 0].plot(train_losses, color="green")
ax[0, 0].set(xlabel="Epoch", ylabel="Loss")
ax[0, 0].set_title("Training Loss")

ax[0, 1].plot(val_losses, color="orange")
ax[0, 1].set(xlabel="Epoch", ylabel="Loss")
ax[0, 1].set_title("Validation Loss")

ax[1, 0].plot(train_accs, color="green")
ax[1, 0].set(xlabel="Epoch", ylabel="Accuracy")
ax[1, 0].set_title("Training Accuracy")

ax[1, 1].plot(val_accs, color="orange")
ax[1, 1].set(xlabel="Epoch", ylabel="Accuracy")
ax[1, 1].set_title("Validation Accuracy")

plt.show()

# %%
val_target = []
val_predict = []
model.eval()
with torch.no_grad():
    for X_samples, y_samples in val_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        outputs = model(X_samples)

        val_predict.append(outputs.cpu())
        val_target.append(y_samples.cpu())

    val_predict = torch.cat(val_predict)
    val_target = torch.cat(val_target)
    val_acc = compute_accuracy(val_predict, val_target)

    print("Evaluation on val set:")
    print(f"Accuracy: {val_acc}")
# Out:
# Evaluation on val set:
# Accuracy: 0.39742250087077674
